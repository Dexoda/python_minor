# %% [markdown]
# # Plotting Data

# %% [markdown]
# ## 1. Histogram
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.hist.html?highlight=hist#matplotlib.pyplot.hist

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = {'Name':['Adam', 'Belle', 'Carl', 'Daisy', 'Edward','Fiona'],
'Height' : [60,61,63,65,61,60],
'Weight' : [47,89,52,58,50,47]}
df=pd.DataFrame(data)
df.plot(kind='hist')
plt.show()

# %%
df.plot(kind='hist',bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# <i><b>Customising Histogram</b></i>

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = {'Name':['Adam', 'Belle', 'Carl', 'Daisy', 'Edward','Fiona'],
'Height' : [60,61,63,65,61,60],
'Weight' : [47,89,52,58,50,47]}
df=pd.DataFrame(data)
df.plot(kind='hist',edgecolor='Cyan',linewidth=2,linestyle=':',fill=False,hatch='O')
plt.show()

# %% [markdown]
# ## 2. Scatter plot

# %%
import numpy as np
import matplotlib.pyplot as plt
discount= np.array([10,20,30,40,50])
saleInRs=np.array([40000,45000,48000,50000,100000])
plt.scatter(x=discount,y=saleInRs)
plt.title('Sales Vs Discount')
plt.xlabel('Discount offered')
plt.ylabel('Sales in Rs')
plt.show()

# %% [markdown]
# <i><b>Customising Scatter chart</b></i>

# %%
import numpy as np
import matplotlib.pyplot as plt
discount= np.array([10,20,30,40,50])
saleInRs=np.array([40000,45000,48000,50000,100000])
size=discount*10
plt.scatter(x=discount,y=saleInRs,s=size,color='red',linewidth=3,marker='*',edgecolor='blue')
plt.title('Sales Vs Discount')
plt.xlabel('Discount offered')
plt.ylabel('Sales in Rs')
plt.show()

# %% [markdown]
# ## 3. Plotting Quartiles and Box plot

# %% [markdown]
# marks.csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data= pd.read_csv('marks.csv')
df= pd.DataFrame(data)
df.plot(kind='box')
#set title,xlabel,ylabel
plt.title('Performance Analysis')
plt.xlabel('Subjects')
plt.ylabel('Marks')
plt.show()

# %% [markdown]
# ## 4. Multiseries Stacked Bar Chart

# %%
series1 = np.array([3,4,5,3])
series2 = np.array([1,2,2,5])
series3 = np.array([2,3,3,4])
index = np.arange(4)
plt.axis([-0.5,3.5,0,15])
plt.title('A Multiseries Stacked Bar Chart')
plt.bar(index,series1,color='r')
plt.bar(index,series2,color='b',bottom=series1)
plt.bar(index,series3,color='g',bottom=(series2+series1))
plt.xticks(index,['Jan18','Feb18','Mar18','Apr18'])
plt.show()

# %%
series1 = np.array([3,4,5,3])
series2 = np.array([1,2,2,5])
series3 = np.array([2,3,3,4])
index = np.arange(4)
plt.axis([0,15,-0.5,3.5])
plt.title('A Multiseries Horizontal Stacked Bar Chart')
plt.barh(index,series1,color='r')
plt.barh(index,series2,color='b',left=series1)
plt.barh(index,series3,color='g',left=(series2+series1))
plt.yticks(index,['Jan18','Feb18','Mar18','Apr18'])
plt.show()

# %%
series1 = np.array([3,4,5,3])
series2 = np.array([1,2,2,5])
series3 = np.array([2,3,3,4])
index = np.arange(4)
plt.axis([0,15,-0.5,3.5])
plt.title('A Multiseries Horizontal Stacked Bar Chart')
plt.barh(index,series1,color='w',hatch='xx')
plt.barh(index,series2,color='w',hatch='///',left=series1)
plt.barh(index,series3,color='w',hatch='\\\\\\',left=(series2+series1))
plt.yticks(index,['Jan18','Feb18','Mar18','Apr18'])
plt.show()

# %%
import pandas as pd

data = {'series1': [1,3,4,3,5],
        'series2': [2,4,5,2,4],
        'series3': [3,2,3,1,3]}
df = pd.DataFrame(data)
df.plot(kind='bar',stacked=True)
plt.show()

# %% [markdown]
# ## 5. Pie chart

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.DataFrame({'mass': [0.330, 4.87 , 5.97],
'radius': [2439.7, 6051.8, 6378.1]},
index=['Mercury', 'Venus', 'Earth'])
df.plot(kind='pie',y='mass')
plt.show()

# %%
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]
explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %% [markdown]
# # Exercise 1

# %% [markdown]
# <b> Present the data above using a histogram plot and stacked bar chart(by mounth) </b>
# <hr>
# <b>MAXIMUM:</b>
#
# Average high temperature in January: 0.7°C
#
# Average high temperature in February: 2.2°C
#
# Average high temperature in March: 8.7°C
#
# Average high temperature in April: 17.3°C
#
# Average high temperature in May: 22.4°C
#
# Average high temperature in June: 27.5°C
#
# Average high temperature in July: 30°C
#
# Average high temperature in August: 29.4°C
#
# Average high temperature in September: 24.2°C
#
# Average high temperature in October: 16.3°C
#
# Average high temperature in November: 8.2°C
#
# Average high temperature in December: 2.3°C
#
# <b>MINIMUM:</b>
#
# Average low temperature in January: -8.4°C
#
# Average low temperature in February: -6.9°C
#
# Average low temperature in March: -1.1°C
#
# Average low temperature in April: 5.9°C
#
# Average low temperature in May: 11°C
#
# Average low temperature in June: 15.8°C
#
# Average low temperature in July: 18°C
#
# Average low temperature in August: 16.9°C
#
# Average low temperature in September: 11.5°C
#
# Average low temperature in October: 4.6°C
#
# Average low temperature in November: -1.3°C
#
# Average low temperature in December: -6.4°C

# %%
import pandas as pd
import matplotlib.pyplot as plt

# ---- DATA ----
months = ["January", "February", "March", "April", "May", "June",
          "July", "August", "September", "October", "November", "December"]

max_temp = [0.7, 2.2, 8.7, 17.3, 22.4, 27.5, 30.0, 29.4, 24.2, 16.3, 8.2, 2.3]
min_temp = [-8.4, -6.9, -1.1, 5.9, 11.0, 15.8, 18.0, 16.9, 11.5, 4.6, -1.3, -6.4]

df = pd.DataFrame({
    "Month": months,
    "Max Temperature (°C)": max_temp,
    "Min Temperature (°C)": min_temp
})

# ---- HISTOGRAM ----
plt.figure(figsize=(10, 5))
plt.hist([df["Max Temperature (°C)"], df["Min Temperature (°C)"]])
plt.title("Temperature Histogram (Max & Min)")
plt.xlabel("Temperature (°C)")
plt.ylabel("Frequency")
plt.legend(["Max Temperature", "Min Temperature"])
plt.show()

# ---- STACKED BAR CHART ----
plt.figure(figsize=(12, 6))
plt.bar(df["Month"], df["Max Temperature (°C)"])
plt.bar(df["Month"], df["Min Temperature (°C)"], bottom=df["Max Temperature (°C)"])
plt.title("Stacked Bar Chart of Monthly Temperatures")
plt.xlabel("Month")
plt.ylabel("Temperature (°C)")
plt.xticks(rotation=45)
plt.legend(["Max Temperature", "Min Temperature"])
plt.show()

# %% [markdown]
# # Exercise 2.

# %% [markdown]
# Present the data above with using customized pie charts.
#  <b> Area</b> pie chart -> plot() and <b> Population</b>  pie chart -> pie()
# https://en.wikipedia.org/wiki/Regions_of_Kazakhstan

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# === Data from Wikipedia (Regions of Kazakhstan) ===
regions = [
    "Akmola", "Aktobe", "Almaty (city)", "Almaty Region", "Nur-Sultan",
    "Atyrau", "Baikonur", "East Kazakhstan", "Jambyl", "Karaganda",
    "Kostanay", "Kyzylorda", "Mangystau", "North Kazakhstan",
    "Pavlodar", "Shymkent", "Turkistan", "West Kazakhstan"
]

area = [
    146219, 300629, 319, 223924, 710,
    118631, 57, 283226, 144264, 427982,
    196001, 226019, 165642, 97993,
    124800, 1170, 117249, 151339
]

population = [
    737495, 757768, 1365632, 1807894, 613006,
    510377, 36175, 1396593, 1022129, 1341700,
    885570, 678794, 485392, 596535,
    742475, 603499, 2469357, 598880
]

# Create DataFrame
df = pd.DataFrame({
    "Region": regions,
    "Area": area,
    "Population": population
})

# ---------------- PIE CHART 1 (Area, using plot()) ----------------
plt.figure(figsize=(9, 9))
df.set_index("Region")["Area"].plot(kind="pie", autopct="%1.1f%%")
plt.title("Kazakhstan Regions — Area Distribution")
plt.ylabel("")  # Remove default label
plt.show()

# ---------------- PIE CHART 2 (Population, using pie()) ----------------
plt.figure(figsize=(9, 9))
plt.pie(df["Population"], labels=df["Region"], autopct="%1.1f%%")
plt.title("Kazakhstan Regions — Population Distribution")
plt.show()
